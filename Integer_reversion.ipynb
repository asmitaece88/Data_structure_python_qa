# %% [markdown]
# Our task is to design an efficient algorithm to reverse a given integer. For example if the input of the algorithm is 1234 then the output should be 4321

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def reverse_integer(n):
    reversed_int=0
    remainder=0
    
    while (n>0):
        remainder = n%10
        reversed_int=reversed_int*10 +remainder 
        
        n=n//10 ## in ordeer to make sure the number diviided by 10 is not a float m rather an integer we use //
    return reversed_int

# %%
print(reverse_integer(1234))
# Out:
# 4321
